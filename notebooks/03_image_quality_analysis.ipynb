# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()

if not (PROJECT_ROOT / "data" / "raw").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))

from src.phase2_cleaning import (
    save_corrupted_images,
    run_quality_analysis,
)

# %%
corrupted = save_corrupted_images(PROJECT_ROOT)
corrupted.head()
# Out:
# Corrupted/unreadable images recorded: 0
# Empty DataFrame
# Columns: [image_key, image_id, dataset, image_path, reason]
# Index: []

# %%
quality = run_quality_analysis(
    PROJECT_ROOT,
    workers=4,
)

quality.head()
# Out:
# Quality analysis: 1,000/42,541
# Quality analysis: 2,000/42,541
# Quality analysis: 3,000/42,541
# Quality analysis: 4,000/42,541
# Quality analysis: 5,000/42,541
# Quality analysis: 6,000/42,541
# Quality analysis: 7,000/42,541
# Quality analysis: 8,000/42,541
# Quality analysis: 9,000/42,541
# Quality analysis: 10,000/42,541
# Quality analysis: 11,000/42,541
# Quality analysis: 12,000/42,541
# Quality analysis: 13,000/42,541
# Quality analysis: 14,000/42,541
# Quality analysis: 15,000/42,541
# Quality analysis: 16,000/42,541
# Quality analysis: 17,000/42,541
# Quality analysis: 18,000/42,541
# Quality analysis: 19,000/42,541
# Quality analysis: 20,000/42,541
# Quality analysis: 21,000/42,541
# Quality analysis: 22,000/42,541
# Quality analysis: 23,000/42,541
# Quality analysis: 24,000/42,541
# Quality analysis: 25,000/42,541
# Quality analysis: 26,000/42,541
# Quality analysis: 27,000/42,541
# Quality analysis: 28,000/42,541
# Quality analysis: 29,000/42,541
# Quality analysis: 30,000/42,541
# Quality analysis: 31,000/42,541
# Quality analysis: 32,000/42,541
# Quality analysis: 33,000/42,541
# Quality analysis: 34,000/42,541
# Quality analysis: 35,000/42,541
# Quality analysis: 36,000/42,541
# Quality analysis: 37,000/42,541
# Quality analysis: 38,000/42,541
# Quality analysis: 39,000/42,541
# Quality analysis: 40,000/42,541
# Quality analysis: 41,000/42,541
# Quality analysis: 42,000/42,541
# Quality analysis: 42,541/42,541
#                  image_key  brightness_mean  contrast_std  \
# 0  aptos__2b8228ecc008b575        66.384793     31.165278
# 1  aptos__8a58801bb4e89fda        50.990446     31.261409
# 2  aptos__11b2efaae2c39263        22.482814     26.219367
# 3  aptos__c8827d05711175da        74.232948     43.365525
# 4  aptos__f9409e06017fe46c        85.032720     46.333070
#
#    sharpness_laplacian_var  dark_pixel_fraction  bright_pixel_fraction  \
# 0                78.010500             0.167199                    0.0
# 1                46.768915             0.254481                    0.0
# 2                49.392446             0.526733                    0.0
# 3                29.479918             0.253957                    0.0
# 4               291.557499             0.211308                    0.0
#
#   quality_flag_auto  quality_label quality_label_source
# 0              pass           <NA>                 <NA>
# 1              pass           <NA>                 <NA>
# 2         very_dark           <NA>                 <NA>
# 3              pass           <NA>                 <NA>
# 4              pass           <NA>                 <NA>
